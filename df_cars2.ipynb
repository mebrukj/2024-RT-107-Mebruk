# %%
from numpy import place
import pandas as pd
df_cars2 = pd.read_csv(r'C:\Developer\auto.csv')
import seaborn as sns
sns.boxplot(x="drive-wheels", y="price", data=df_cars2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 df_cars2 = pd.read_csv(r'C:\Developer\auto.csv')
#       5 import seaborn as sns
# ----> 6 sns.boxplot(x="drive-wheels", y="price", data=df_cars2)
#
# File c:\Users\Learner_9ZH3Z157\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
# ...
